# %% [markdown]
# # 🐷 Susie Package Test Notebook

# %% [markdown]
# ### 🔷 Import the necessary python libraries and Susie objects.

# %% [markdown]
# Importing the package from Test PyPi

# %%
# %pip install susie==1.0.8
# Out:
# Requirement already satisfied: susie==1.0.8 in c:\users\holly\onedrive\desktop\bsuresearch\susie\venv\lib\site-packages (1.0.8)
# Requirement already satisfied: numpy in c:\users\holly\onedrive\desktop\bsuresearch\susie\venv\lib\site-packages (from susie==1.0.8) (1.26.3)
# Requirement already satisfied: scipy in c:\users\holly\onedrive\desktop\bsuresearch\susie\venv\lib\site-packages (from susie==1.0.8) (1.12.0)
# Requirement already satisfied: matplotlib in c:\users\holly\onedrive\desktop\bsuresearch\susie\venv\lib\site-packages (from susie==1.0.8) (3.8.2)
# Requirement already satisfied: astropy in c:\users\holly\onedrive\desktop\bsuresearch\susie\venv\lib\site-packages (from susie==1.0.8) (6.0.0)
# Requirement already satisfied: pyerfa>=2.0 in c:\users\holly\onedrive\desktop\bsuresearch\susie\venv\lib\site-packages (from astropy->susie==1.0.8) (2.0.1.1)
# Requirement already satisfied: astropy-iers-data>=0.2023.10.30.0.29.53 in c:\users\holly\onedrive\desktop\bsuresearch\susie\venv\lib\site-packages (from astropy->susie==1.0.8) (0.2024.2.5.0.30.52)
# Requirement already satisfied: PyYAML>=3.13 in c:\users\holly\onedrive\desktop\bsuresearch\susie\venv\lib\site-packages (from astropy->susie==1.0.8) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in c:\users\holly\onedrive\desktop\bsuresearch\susie\venv\lib\site-packages (from astropy->susie==1.0.8) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\holly\onedrive\desktop\bsuresearch\susie\venv\lib\site-packages (from matplotlib->susie==1.0.8) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\holly\onedrive\desktop\bsuresearch\susie\venv\lib\site-packages (from matplotlib->susie==1.0.8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\holly\onedrive\desktop\bsuresearch\susie\venv\lib\site-packages (from matplotlib->susie==1.0.8) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\holly\onedrive\desktop\bsuresearch\susie\venv\lib\site-packages (from matplotlib->susie==1.0.8) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\holly\onedrive\desktop\bsuresearch\susie\venv\lib\site-packages (from matplotlib->susie==1.0.8) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\holly\onedrive\desktop\bsuresearch\susie\venv\lib\site-packages (from matplotlib->susie==1.0.8) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\holly\onedrive\desktop\bsuresearch\susie\venv\lib\site-packages (from matplotlib->susie==1.0.8) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\holly\onedrive\desktop\bsuresearch\susie\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->susie==1.0.8) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from susie.transit_times import TransitTimes
from susie.ephemeris import Ephemeris
import matplotlib.pyplot as plt
from astropy import coordinates as coords
from astropy import units as u
from astropy import time

# %% [markdown]
# ### 🔷 **STEP 1:** Add your transit data to the TransitTimes object.

# %% [markdown]
# ❗️**IMPORTANT:** Use either code block below depending on your data needs. The first code block contains values pulled from a CSV file. The second has hard coded values.
#
# <small>NOTE: You can use any method and/or file type to upload your data. Just make sure the resulting variables (epoch, mid transit times, and mid transit time errors) are numpy arrays</small>

# %% [markdown]
# Can use this code block if you have the **CSV file**

# %%
# STEP 1: Upload data
filepath = "./WASP12b_transit_ephemeris.csv" # IMPORTANT: Change to your own filepath
# filepath = "ENTER YOUR FILEPATH HERE"
data = np.genfromtxt(filepath, delimiter=',', names=True)
# STEP 2: Break data up into epochs, mid transit times, and error
epochs = data["epoch"]
mid_transit_times = data["transit_time"]
mid_transit_times_err = data["sigma_transit_time"]
# STEP 2.5 (Optional): Make sure the epochs are integers and not floats
epochs = epochs.astype('int')

# %% [markdown]
# Can use this code block if you do not have CSV file, this is **hard coded**

# %%
# Hard Coded Data
# STEP 1: Upload data from file
epoch_data = [-1640.0, -1346.0, -1342.0, -1067.0, -1061.0, -1046.0, -1038.0, -1004.0, -1003.0, -985.0, -963.0, -743.0, -739.0, -729.0, -728.0, -721.0, -699.0, -699.0, -677.0, -655.0, -648.0, -646.0, -645.0, -643.0, -625.0, -393.0, -383.0, -382.0, -380.0, -368.0, -353.0, -350.0, -329.0, -328.0, -327.0, -324.0, -323.0, -317.0, -316.0, -307.0, -306.0, -296.0, -295.0, -294.0, -293.0, -283.0, -275.0, -274.0, -55.0, -51.0, -29.0, -21.0, -19.0, -7.0, -3.0, 0.0, 13.0, 21.0, 22.0, 274.0, 275.0, 276.0, 277.0, 297.0, 298.0, 320.0, 324.0, 327.0, 328.0, 329.0, 338.0, 341.0, 351.0, 356.0, 365.0, 372.0, 379.0, 381.0, 382.0, 624.0, 646.0, 648.0, 678.0, 679.0, 691.0, 692.0, 698.0, 699.0, 731.0, 953.0, 994.0, 995.0, 1027.0, 1028.0, 1050.0, 1252.0, 1270.0, 1281.0, 1284.0, 1302.0, 1303.0, 1338.0, 1339.0, 1344.0, 1345.0, 1348.0, 1352.0, 1352.0, 1357.0, 1359.0, 1370.0, 1377.0, 1378.0, 1379.0, 1577.0, 1599.0, 1608.0, 1620.0, 1621.0, 1624.0, 1666.0, 1667.0, 1674.0, 1676.0, 1678.0, 1695.0, 1695.0, 1696.0, 1699.0, 1701.0, 1701.0, 1702.0, 1702.0, 1705.0, 1716.0, 1930.0, 1985.0, 2006.0, 2017.0]
mid_transit_time_data = [2454515.525, 2454836.403, 2454840.769, 2455140.91, 2455147.459, 2455163.831, 2455172.561, 2455209.669, 2455210.762, 2455230.407, 2455254.419, 2455494.53, 2455498.896, 2455509.81, 2455510.902, 2455518.541, 2455542.552, 2455542.553, 2455566.564, 2455590.576, 2455598.216, 2455600.398, 2455601.49, 2455603.673, 2455623.318, 2455876.528, 2455887.442, 2455888.533, 2455890.716, 2455903.814, 2455920.184, 2455923.459, 2455946.378, 2455947.47, 2455948.561, 2455951.835, 2455952.927, 2455959.475, 2455960.567, 2455970.389, 2455971.481, 2455982.395, 2455983.487, 2455984.578, 2455985.67, 2455996.584, 2456005.315, 2456006.406, 2456245.427, 2456249.794, 2456273.805, 2456282.536, 2456284.719, 2456297.816, 2456302.182, 2456305.455, 2456319.644, 2456328.376, 2456329.467, 2456604.505, 2456605.596, 2456606.688, 2456607.779, 2456629.607, 2456630.699, 2456654.71, 2456659.076, 2456662.35, 2456663.441, 2456664.533, 2456674.356, 2456677.63, 2456688.544, 2456694.002, 2456703.824, 2456711.464, 2456719.104, 2456721.287, 2456722.378, 2456986.502, 2457010.513, 2457012.696, 2457045.438, 2457046.53, 2457059.627, 2457060.718, 2457067.267, 2457068.358, 2457103.284, 2457345.579, 2457390.327, 2457391.418, 2457426.343, 2457427.435, 2457451.446, 2457671.913, 2457691.559, 2457703.564, 2457706.838, 2457726.484, 2457727.575, 2457765.775, 2457766.866, 2457772.324, 2457773.415, 2457776.689, 2457781.054, 2457781.056, 2457786.512, 2457788.695, 2457800.7, 2457808.34, 2457809.432, 2457810.523, 2458026.624, 2458050.635, 2458060.459, 2458073.555, 2458074.647, 2458077.921, 2458123.76, 2458124.852, 2458132.491, 2458134.675, 2458136.858, 2458155.41, 2458155.412, 2458156.503, 2458159.778, 2458161.96, 2458161.96, 2458163.051, 2458163.051, 2458166.326, 2458178.331, 2458411.895, 2458471.923, 2458494.843, 2458506.848]
mid_transit_times_uncertainties_data = [0.00043, 0.00028, 0.00062, 0.00042, 0.00043, 0.00032, 0.00036, 0.00046, 0.00041, 0.00019, 0.00043, 0.00072, 0.00079, 0.00037, 0.00031, 0.0004, 0.0004, 0.00028, 0.00028, 0.00068, 0.00035, 0.00029, 0.00024, 0.00029, 0.00039, 0.00027, 0.00021, 0.00027, 0.00024, 0.00032, 0.00031, 0.00022, 0.00018, 0.00017, 0.00033, 0.00011, 0.0001, 0.00017, 0.00032, 0.00039, 0.00035, 0.00034, 0.00035, 0.00032, 0.00042, 0.00037, 0.00037, 0.00031, 0.00033, 0.00039, 0.0003, 0.0003, 0.0003, 0.0003, 0.00046, 0.00024, 0.00038, 0.00027, 0.00029, 0.00021, 0.0003, 0.00033, 0.00071, 0.00019, 0.00043, 0.00034, 0.00034, 0.00019, 0.00019, 0.00031, 0.00028, 0.00032, 0.0004, 0.00029, 0.00029, 0.00025, 0.00034, 0.00034, 0.00046, 0.00043, 0.00039, 0.00049, 0.00046, 0.00049, 0.00035, 0.00036, 0.00022, 0.0002, 0.00031, 0.00042, 0.00033, 0.00033, 0.00055, 0.00023, 0.00021, 0.00035, 0.00025, 0.00034, 0.00037, 0.00028, 0.00023, 0.00028, 0.00039, 0.00024, 0.00022, 0.00029, 0.00043, 0.00036, 0.00026, 0.00048, 0.00032, 0.0004, 0.00018, 0.00021, 0.00056, 0.00023, 0.0003, 0.00022, 0.00034, 0.00028, 0.00027, 0.00035, 0.00031, 0.00032, 0.00033, 0.0005, 0.00031, 0.00032, 0.00091, 0.00035, 0.00026, 0.00021, 0.00034, 0.00034, 0.00038, 0.0004, 0.00026, 0.0003, 0.00044]
# STEP 2: Break data up into epochs, mid transit times, and error
# epochs = epoch_data - np.min(epoch_data)
# mid_transit_times = mid_transit_time_data - np.min(mid_transit_time_data)
# mid_transit_times_err = np.array(mid_transit_times_uncertainties_data) #added np.array HV
# STEP 2.5 (Optional): Make sure the epochs are integers and not floats
epochs = epochs.astype(np.int64)

# %%
type(epochs)
epochs.dtype
type(epochs[0])
#error here with epochs not having int values ut we're only giving it int values. Look at on 4/11 - HV, creates a cascade of objects not being defined
# Out:
# numpy.int64

# %% [markdown]
# ❗️ **IMPORTANT**: Our timing data is going to be in JD TDB timing system and scale (AKA Barycentric Julian Date).
#
# We **can** input data with a different timing scale and system, and the TransitTimes object will automatically correct it to JD TDB. HOWEVER, we will have to put in the coordinates of the object (RA and Dec in degrees) and the observatory the observations were taken from (in lon and lat in degrees). You have the option to omit observatory coordinates if you do not know them, the function will use the gravitational center of the Earth (x, y, x=0, 0, 0).

# %% [markdown]
# Example with JD TDB timing system and scale.

# %%
# STEP 3: Create new transit times object with above data
transit_times_obj1 = TransitTimes('jd', epochs, mid_transit_times, mid_transit_times_err, time_scale='tdb')
# STEP 4 (Optional): To check that the resulting data is correct, you can print each variable and the corresponding data using this command:
# print(vars(transit_times_obj1))

# %% [markdown]
# Example with JD UTC timing system and scale. (NOTE: Don't be scared of the warnings, nothing is wrong.)
#
# <small>Using RA and Dec of WASP 12-b and lon, lat of Boise State for observatory.</small>

# %%
# STEP 3: Create new transit times object with above data
transit_times_obj1 = TransitTimes('jd', epochs, mid_transit_times, mid_transit_times_err, object_ra=97.64, object_dec=29.67, observatory_lat=43.60, observatory_lon=-116.21)
# Out:
# WARNING:root:Recieved time format jd and time scale None. Correcting all times to BJD timing system with TDB time scale. If this is incorrect, please set the time format and time scale for TransitTime object.
# WARNING:root:Using ICRS coordinates in degrees of RA and Dec (97.64, 29.67) for time correction. Using geodetic Earth coordinates in degrees of longitude and latitude (-116.21, 43.6) for time correction.
# WARNING: Tried to get polar motions for times before IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# WARNING:astropy:Tried to get polar motions for times before IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary.
# C:\Users\holly\OneDrive\Desktop\BSUResearch\susie\venv\Lib\site-packages\erfa\core.py:154: ErfaWarning: ERFA function "utctai" yielded 139 of "dubious year (Note 3)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# C:\Users\holly\OneDrive\Desktop\BSUResearch\susie\venv\Lib\site-packages\erfa\core.py:154: ErfaWarning: ERFA function "utcut1" yielded 139 of "dubious year (Note 3)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# C:\Users\holly\OneDrive\Desktop\BSUResearch\susie\venv\Lib\site-packages\erfa\core.py:154: ErfaWarning: ERFA function "taiutc" yielded 139 of "dubious year (Note 4)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# C:\Users\holly\OneDrive\Desktop\BSUResearch\susie\venv\Lib\site-packages\erfa\core.py:154: ErfaWarning: ERFA function "epv00" yielded 139 of "warning: date outsidethe range 1900-2100 AD"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),

# %% [markdown]
# ### 🔷 **STEP 2:** Create the Ephemeris object and add your TransitTimes object.

# %%
ephemeris_obj1 = Ephemeris(transit_times_obj1)

# %% [markdown]
# ### 🔷 **STEP 3:** Fit your transit time data to an ephemeris model. You can specify what type of model with the options 'linear' or 'quadratic'.

# %%
# Getting a linear model will solve for period and conjuction time (and their respective errors)
linear_model_data = ephemeris_obj1.get_model_ephemeris('linear')

# %% [markdown]
# Calling `get_model_ephemeris` will return a dictionary of data. You can view the data returned from this if you run `print(linear_model_data)`. Now you can use the linear_model_data dictionary for plotting methods, such as the ones below. You can use the same process for a quadratic model ephemeris (shown below).

# %%
linear_model_data
# Out:
# {'period': 1.0914196485982803,
#  'period_err': 3.1496749422701027e-07,
#  'conjunction_time': 0.003092872392577495,
#  'conjunction_time_err': 0.0007128109688698606,
#  'model_type': 'linear',
#  'model_data': array([3.09287239e-03, 3.20880470e+02, 3.25246148e+02, 6.25386552e+02,
#         6.31935069e+02, 6.48306364e+02, 6.57037721e+02, 6.94145989e+02,
#         6.95237409e+02, 7.14882963e+02, 7.38894195e+02, 9.79006518e+02,
#         9.83372196e+02, 9.94286393e+02, 9.95377812e+02, 1.00301775e+03,
#         1.02702898e+03, 1.02702898e+03, 1.05104021e+03, 1.07505145e+03,
#         1.08269138e+03, 1.08487422e+03, 1.08596564e+03, 1.08814848e+03,
#         1.10779404e+03, 1.36100339e+03, 1.37191759e+03, 1.37300901e+03,
#         1.37519185e+03, 1.38828889e+03, 1.40466018e+03, 1.40793444e+03,
#         1.43085425e+03, 1.43194567e+03, 1.43303709e+03, 1.43631135e+03,
#         1.43740277e+03, 1.44395129e+03, 1.44504271e+03, 1.45486548e+03,
#         1.45595690e+03, 1.46687110e+03, 1.46796252e+03, 1.46905394e+03,
#         1.47014536e+03, 1.48105956e+03, 1.48979091e+03, 1.49088233e+03,
#         1.72990324e+03, 1.73426891e+03, 1.75828015e+03, 1.76701150e+03,
#         1.76919434e+03, 1.78229138e+03, 1.78665706e+03, 1.78993132e+03,
#         1.80411977e+03, 1.81285113e+03, 1.81394255e+03, 2.08898030e+03,
#         2.09007172e+03, 2.09116314e+03, 2.09225456e+03, 2.11408295e+03,
#         2.11517437e+03, 2.13918560e+03, 2.14355128e+03, 2.14682554e+03,
#         2.14791696e+03, 2.14900838e+03, 2.15883116e+03, 2.16210542e+03,
#         2.17301961e+03, 2.17847671e+03, 2.18829949e+03, 2.19593943e+03,
#         2.20357936e+03, 2.20576220e+03, 2.20685362e+03, 2.47097718e+03,
#         2.49498841e+03, 2.49717125e+03, 2.52991384e+03, 2.53100526e+03,
#         2.54410229e+03, 2.54519371e+03, 2.55174223e+03, 2.55283365e+03,
#         2.58775908e+03, 2.83005424e+03, 2.87480245e+03, 2.87589387e+03,
#         2.91081930e+03, 2.91191072e+03, 2.93592195e+03, 3.15638872e+03,
#         3.17603427e+03, 3.18803989e+03, 3.19131415e+03, 3.21095970e+03,
#         3.21205112e+03, 3.25025081e+03, 3.25134223e+03, 3.25679932e+03,
#         3.25789074e+03, 3.26116500e+03, 3.26553068e+03, 3.26553068e+03,
#         3.27098778e+03, 3.27317062e+03, 3.28517624e+03, 3.29281617e+03,
#         3.29390759e+03, 3.29499901e+03, 3.51110010e+03, 3.53511133e+03,
#         3.54493411e+03, 3.55803115e+03, 3.55912257e+03, 3.56239683e+03,
#         3.60823645e+03, 3.60932787e+03, 3.61696781e+03, 3.61915065e+03,
#         3.62133349e+03, 3.63988762e+03, 3.63988762e+03, 3.64097904e+03,
#         3.64425330e+03, 3.64643614e+03, 3.64643614e+03, 3.64752756e+03,
#         3.64752756e+03, 3.65080182e+03, 3.66280743e+03, 3.89637124e+03,
#         3.95639932e+03, 3.97931913e+03, 3.99132475e+03])}

# %%
# Now we can plot this model
ephemeris_obj1.plot_model_ephemeris(linear_model_data, save_plot=False)

# %%
# Getting a quadratic model will solve for period, conjuction time, and period change per epoch (and their respective errors)
quadratic_model_data = ephemeris_obj1.get_model_ephemeris('quadratic')

# %%
quadratic_model_data
# Out:
# {'conjunction_time': 0.0016682851583146132,
#  'conjunction_time_err': 0.0014595461023369455,
#  'period': 1.0914213783138003,
#  'period_err': 1.5856377650608515e-06,
#  'period_change_by_epoch': -8.385455056387949e-10,
#  'period_change_by_epoch_err': 7.542908911207996e-10,
#  'model_type': 'quadratic',
#  'model_data': array([1.66828516e-03, 3.20879517e+02, 3.25245202e+02, 6.25385980e+02,
#         6.31934506e+02, 6.48305819e+02, 6.57037186e+02, 6.94145495e+02,
#         6.95236916e+02, 7.14882491e+02, 7.38893749e+02, 9.79006307e+02,
#         9.83371990e+02, 9.94286196e+02, 9.95377617e+02, 1.00301756e+03,
#         1.02702881e+03, 1.02702881e+03, 1.05104007e+03, 1.07505132e+03,
#         1.08269126e+03, 1.08487410e+03, 1.08596552e+03, 1.08814837e+03,
#         1.10779394e+03, 1.36100348e+03, 1.37191768e+03, 1.37300910e+03,
#         1.37519194e+03, 1.38828898e+03, 1.40466029e+03, 1.40793455e+03,
#         1.43085437e+03, 1.43194579e+03, 1.43303722e+03, 1.43631148e+03,
#         1.43740290e+03, 1.44395142e+03, 1.44504284e+03, 1.45486562e+03,
#         1.45595704e+03, 1.46687124e+03, 1.46796266e+03, 1.46905408e+03,
#         1.47014550e+03, 1.48105971e+03, 1.48979107e+03, 1.49088249e+03,
#         1.72990350e+03, 1.73426918e+03, 1.75828042e+03, 1.76701178e+03,
#         1.76919462e+03, 1.78229166e+03, 1.78665734e+03, 1.78993160e+03,
#         1.80412006e+03, 1.81285142e+03, 1.81394284e+03, 2.08898065e+03,
#         2.09007207e+03, 2.09116349e+03, 2.09225491e+03, 2.11408330e+03,
#         2.11517472e+03, 2.13918596e+03, 2.14355164e+03, 2.14682590e+03,
#         2.14791732e+03, 2.14900874e+03, 2.15883151e+03, 2.16210577e+03,
#         2.17301997e+03, 2.17847707e+03, 2.18829985e+03, 2.19593978e+03,
#         2.20357972e+03, 2.20576256e+03, 2.20685398e+03, 2.47097752e+03,
#         2.49498875e+03, 2.49717159e+03, 2.52991417e+03, 2.53100559e+03,
#         2.54410262e+03, 2.54519404e+03, 2.55174256e+03, 2.55283398e+03,
#         2.58775940e+03, 2.83005448e+03, 2.87480267e+03, 2.87589409e+03,
#         2.91081950e+03, 2.91191092e+03, 2.93592214e+03, 3.15638879e+03,
#         3.17603433e+03, 3.18803994e+03, 3.19131419e+03, 3.21095973e+03,
#         3.21205115e+03, 3.25025081e+03, 3.25134223e+03, 3.25679933e+03,
#         3.25789075e+03, 3.26116500e+03, 3.26553068e+03, 3.26553068e+03,
#         3.27098777e+03, 3.27317061e+03, 3.28517622e+03, 3.29281615e+03,
#         3.29390757e+03, 3.29499899e+03, 3.51109990e+03, 3.53511111e+03,
#         3.54493388e+03, 3.55803091e+03, 3.55912232e+03, 3.56239658e+03,
#         3.60823616e+03, 3.60932758e+03, 3.61696751e+03, 3.61915035e+03,
#         3.62133319e+03, 3.63988730e+03, 3.63988730e+03, 3.64097872e+03,
#         3.64425298e+03, 3.64643581e+03, 3.64643581e+03, 3.64752723e+03,
#         3.64752723e+03, 3.65080149e+03, 3.66280709e+03, 3.89637065e+03,
#         3.95639866e+03, 3.97931844e+03, 3.99132404e+03])}

# %%
ephemeris_obj1.plot_model_ephemeris(quadratic_model_data, save_plot=False)

# %% [markdown]
# We can also plot the model uncertainties with the `plot_timing_uncertainties` method.

# %%
ephemeris_obj1.plot_timing_uncertainties(linear_model_data, save_plot=False)

# %%
ephemeris_obj1.plot_timing_uncertainties(quadratic_model_data, save_plot=False)

# %% [markdown]
# We can get the BIC value for a specific model fit using the model data dictionaries returned from the `get_model_ephemeris` method.

# %%
linear_bic_value = ephemeris_obj1.calc_bic(linear_model_data)
quadratic_bic_value = ephemeris_obj1.calc_bic(quadratic_model_data)

print(f"Linear Model BIC: {linear_bic_value}\nQuadratic Model BIC: {quadratic_bic_value}")
# Out:
# Linear Model BIC: 30.715948345791855
# Quadratic Model BIC: 34.41719407684216

# %% [markdown]
# And we can also get a delta BIC value. We do not need to input any data for this method. It will create the linear and quadratic models for you and calculate the BIC and delta BIC values. However, it **ONLY returns the delta BIC value** and not the other data calculated.

# %%
delta_bic_value = ephemeris_obj1.calc_delta_bic()

print(f"Delta BIC: {delta_bic_value}")
# Out:
# Delta BIC: -3.701245731050303

# %% [markdown]
# The last two methods accessible to the user are an OC plotting method and a running delta BIC plotting method.

# %% [markdown]
# The OC plot for now just plots the observed minus calculated points (calculated with $x=E$, $y=T_0-PE$, $y_{\rm err}=\sigma T_0$ and a curve with the quadratic term ($x=E$, $y=0.5 \frac{dP}{dE} (E - {\rm median} (E))^2$).

# %%
ephemeris_obj1.plot_oc_plot()

# %% [markdown]
# This is the `plot_running_delta_bic` method. This is a work in progress, but the basic data is in there.

# %%
ephemeris_obj1.plot_running_delta_bic()
